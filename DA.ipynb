# %%
import pandas as pd

df = pd.read_csv('owid-energy-data.csv')

df_asia = df[df['country'] == 'Asia']

df_asia.tail()
# Out:
#      country  year iso_code    population  gdp  biofuel_cons_change_pct  \
# 1323    Asia  2019      NaN  4.627739e+09  NaN                   26.987
# 1324    Asia  2020      NaN  4.663087e+09  NaN                    5.907
# 1325    Asia  2021      NaN  4.693332e+09  NaN                    8.219
# 1326    Asia  2022      NaN  4.721383e+09  NaN                   10.889
# 1327    Asia  2023      NaN  4.751820e+09  NaN                   14.130
#
#       biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 1323                   34.605                   35.186              162.833
# 1324                    9.619                   36.982              172.452
# 1325                   14.173                   39.764              186.625
# 1326                   20.322                   43.832              206.948
# 1327                   29.243                   49.705              236.190
#
#       biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# ...

# %%
df_asia.describe()
# Out:
#               year    population  gdp  biofuel_cons_change_pct  \
# count   124.000000  1.240000e+02  0.0                23.000000
# mean   1961.500000  2.260274e+09  NaN                34.388304
# std      35.939764  1.246299e+09  NaN                43.683719
# min    1900.000000  9.310214e+08  NaN               -16.046000
# 25%    1930.750000  1.169587e+09  NaN                12.637000
# 50%    1961.500000  1.742969e+09  NaN                25.309000
# 75%    1992.250000  3.337842e+09  NaN                41.952500
# max    2023.000000  4.751820e+09  NaN               199.155000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# count                58.000000                59.000000            59.000000
# mean                  4.072276                 6.796949            30.885644
# std                   9.103374                12.666836            59.006653
# min                 -14.861000                 0.000000             0.000000
# ...
